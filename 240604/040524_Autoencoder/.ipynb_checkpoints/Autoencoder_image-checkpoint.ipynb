# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam
# Out:
# 2024-05-24 01:51:58.758122: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-24 01:51:58.758169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-24 01:51:58.759696: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-24 01:51:58.768187: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# 加載 MNIST 數據
(x_train1, y_train1), (x_test1, y_test1) = mnist.load_data()

# 正規化並重塑數據
# x_train = x_train1[0:100].astype('float32') / 255.
y_test = y_test1 [0:100]
x_test = x_test1[0:100].astype('float32') / 255.
x_train = x_train1.astype('float32') / 255.
# x_test = x_test1.astype('float32') / 255.

x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
# x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (100, 784)

# %%
n = 10  # 顯示幾個數字
plt.figure(figsize=(20, 4))
for i in range(n):
    # 顯示原始數據
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %%
# 定義輸入層的維度
input_dim = x_train.shape[1]  # 784

# 創建輸入層
input_layer = Input(shape=(784,))

# 創建編碼層
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)  # 編碼後的特徵

# 創建解碼層
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)  # 重建的輸出

# 定義 autoencoder 模型
autoencoder = Model(input_layer, decoded)

# 定義編碼器模型
encoder = Model(input_layer, encoded)

# 定義解碼器模型
encoded_input = Input(shape=(32,))
decoder_layer = autoencoder.layers[-3](encoded_input)
decoder_layer = autoencoder.layers[-2](decoder_layer)
decoder_layer = autoencoder.layers[-1](decoder_layer)
decoder = Model(encoded_input, decoder_layer)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
autoencoder.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy')
model_checkpoint = ModelCheckpoint('UNet_Membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
history = autoencoder.fit(x_train, x_train, 
                epochs=200, 
                batch_size=128, 
                shuffle=True, 
                callbacks=[model_checkpoint],
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/200
# 2024-05-24 01:55:23.570541: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570574: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570580: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570584: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570595: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570600: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570604: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.570608: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.574974: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.574999: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575004: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575007: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575018: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575022: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575026: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.575030: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579692: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579711: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579716: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579719: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579729: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579733: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579737: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:23.579741: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287713: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287747: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287752: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287755: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287768: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287773: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287776: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:24.287780: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# W0000 00:00:1716486924.842440   12421 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 451/469 [===========================>..] - ETA: 0s - loss: 0.2025 - accuracy: 0.0107
# 2024-05-24 01:55:26.422131: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422164: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422168: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422172: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422184: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422188: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422192: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.422196: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 469/469 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.0105
# 2024-05-24 01:55:26.881947: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.881980: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.881986: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.881990: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.882002: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.882007: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.882011: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.882015: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885876: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885898: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885903: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885907: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885918: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885923: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885927: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.885930: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893108: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893128: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893132: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893136: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893146: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893151: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893156: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.893160: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955673: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955696: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955701: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955705: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955715: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955720: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955724: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:26.955728: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# Epoch 1: loss improved from inf to 0.20033, saving model to UNet_Membrane.hdf5
# 469/469 [==============================] - 4s 4ms/step - loss: 0.2003 - accuracy: 0.0105 - val_loss: 0.1420 - val_accuracy: 0.0135
# Epoch 2/200
#   1/469 [..............................] - ETA: 1s - loss: 0.1404 - accuracy: 0.0312
# W0000 00:00:1716486927.237668   12424 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#
W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.099026: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.099031: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104049: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104068: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104072: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104076: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104085: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104092: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104095: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:55:39.104099: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# ...
# 2024-05-24 01:59:01.442504: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.442508: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.442512: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447382: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447400: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447405: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447408: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447418: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447424: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447428: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:01.447432: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 456/469 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.0153
# Epoch 197: loss improved from 0.07729 to 0.07728, saving model to UNet_Membrane.hdf5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.0153 - val_loss: 0.0772 - val_accuracy: 0.0155
# Epoch 198/200
#  24/469 [>.............................] - ETA: 0s - loss: 0.0772 - accuracy: 0.0160
# 2024-05-24 01:59:02.527649: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527683: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527688: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527691: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527704: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527710: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527714: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.527718: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.531987: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532014: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532019: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532022: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532034: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532040: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532044: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.532049: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537194: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537216: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537220: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537224: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537234: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537241: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537245: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:02.537249: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 447/469 [===========================>..] - ETA: 0s - loss: 0.0774 - accuracy: 0.0149
# Epoch 198: loss did not improve from 0.07728
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.0150 - val_loss: 0.0774 - val_accuracy: 0.0164
# Epoch 199/200
#  26/469 [>.............................] - ETA: 0s - loss: 0.0772 - accuracy: 0.0138
# 2024-05-24 01:59:03.629493: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629528: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629533: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629537: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629550: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629555: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629560: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.629564: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633809: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633834: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633845: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633849: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633862: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633868: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633872: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.633877: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638863: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638883: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638887: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638891: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638901: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638908: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638912: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:03.638916: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 448/469 [===========================>..] - ETA: 0s - loss: 0.0773 - accuracy: 0.0146
# Epoch 199: loss improved from 0.07728 to 0.07728, saving model to UNet_Membrane.hdf5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.0148 - val_loss: 0.0773 - val_accuracy: 0.0146
# Epoch 200/200
#  26/469 [>.............................] - ETA: 0s - loss: 0.0767 - accuracy: 0.0204
# 2024-05-24 01:59:04.698799: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698831: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698836: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698845: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698858: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698863: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698867: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.698871: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702885: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702908: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702912: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702916: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702927: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702933: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702937: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.702941: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707702: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707720: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707725: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707728: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707738: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707744: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707748: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:04.707752: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 454/469 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.0150
# Epoch 200: loss improved from 0.07728 to 0.07726, saving model to UNet_Membrane.hdf5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.0151 - val_loss: 0.0774 - val_accuracy: 0.0157
# 2024-05-24 01:59:05.789422: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789455: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789460: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789464: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789477: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789482: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789486: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.789490: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793548: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793571: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793576: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793579: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793590: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793595: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793599: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.793603: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798437: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798455: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798460: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798464: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798473: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798479: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798483: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:05.798487: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.

# %%
# autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')
# history = autoencoder.fit(x_train, x_train, 
#                 epochs=200, 
#                 batch_size=256, 
#                 shuffle=True, 
#                 validation_data=(x_test, x_test))
# Out:
# Epoch 1/200
# 2024-05-24 01:59:06.445411: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:06.445446: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:06.445451: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:06
W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.558439: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563258: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563280: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563285: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563289: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563300: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563307: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563312: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.563316: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568111: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568130: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568135: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568138: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568148: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568154: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568158: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:51.568162: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0767 - val_loss: 0.0769
# Epoch 76/200
#  24/235 [==>...........................] - ETA: 0s - loss: 0.0767
# 2024-05-24 01:59:52.126083: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126117: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126122: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126126: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126139: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126145: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126149: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.126154: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130360: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130383: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130388: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130391: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130403: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130410: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130414: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.130418: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135376: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135396: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135400: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135404: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135414: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135420: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135425: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 01:59:52.135428: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')
# ----> 2 history = autoencoder.fit(x_train, x_train,
#       3                 epochs=200,
#       4                 batch_size=256,
#       5                 shuffle=True,
#       6                 validation_data=(x_test, x_test))
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
#  55/313 [====>.........................] - ETA: 0s
# 2024-05-24 02:00:00.325339: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325379: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325384: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325388: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325402: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325409: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325413: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.325417: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330760: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330800: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330806: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330810: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330824: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330829: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330834: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.330851: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336686: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336721: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336725: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336729: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336741: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336746: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336750: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.336754: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357219: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357251: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357256: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357259: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357271: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357275: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357279: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.357283: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# W0000 00:00:1716487200.431110   12422 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 313/313 [==============================] - 0s 876us/step
# 2024-05-24 02:00:00.698170: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698203: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698208: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698212: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698224: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698229: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698233: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.698237: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.854965: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.854997: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855001: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855005: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855016: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855022: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855026: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.855029: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858906: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858937: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858941: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858945: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858956: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858961: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858965: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.858969: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864256: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864278: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864282: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864286: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864296: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864300: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864304: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.864308: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883038: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883060: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883064: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883068: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883079: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883083: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883087: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:00.883091: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 313/313 [==============================] - 0s 791us/step
# 2024-05-24 02:00:01.190120: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190151: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190156: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190160: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190173: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190179: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190183: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:00:01.190187: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.

# %%
n = 10  # 顯示幾個數字
plt.figure(figsize=(20, 4))
for i in range(n):
    # 顯示原始數據
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

#     顯示重建數據
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# 假设 x_test 是你的测试数据集
encoded_imgs = encoder.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 2024-05-24 02:06:29.945923: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945952: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945957: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945961: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945972: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945977: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945981: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.945985: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949507: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949528: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949532: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949536: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949546: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949550: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949554: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.949558: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954236: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954259: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954264: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954267: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954277: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954282: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954285: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2024-05-24 02:06:29.954289: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:163] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.

# %%
from sklearn.decomposition import PCA

# 初始化 PCA，设置降维后的主成分数为2
pca = PCA(n_components=2)
encoded_imgs_2d = pca.fit_transform(encoded_imgs)  # 对编码后的图片应用PCA

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
scatter = plt.scatter(encoded_imgs_2d[:, 0], encoded_imgs_2d[:, 1], c=y_test, cmap='viridis', alpha=0.5)
plt.colorbar(scatter)  # 显示颜色条
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Encoded Images with Labels')
# Out:
# Text(0.5, 1.0, 'PCA of Encoded Images with Labels')
